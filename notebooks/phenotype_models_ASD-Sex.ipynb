# %%
import os
import pandas as pd
import seaborn as sns

from hbn.constants import Defaults
from hbn.visualization import visualize

import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

import plotly.io as pio
pio.renderers.default='notebook'

# pio.renderers.default = 'iframe'

import ipywidgets as widgets       # interactive display
# %config InlineBackend.figure_format = 'svg' # other available formats are: 'retina', 'png', 'jpeg', 'pdf'

# %%
# check models
from hbn.models.predictive_modeling import check_models

check_models(filter='*2023-02-15*')
# Out:
# 2023-02-15_13-56-56-56S: ['No Diagnosis Given', 'Generalized Anxiety Disorder', 'Other Specified Anxiety Disorder', 'Social Anxiety (Social Phobia)', 'Separation Anxiety', 'Specific Phobia', 'Selective Mutism', 'Unspecified Anxiety Disorder', 'Panic Disorder', 'Agoraphobia']: ['DX_01_Cat_new_binarize']
# 2023-02-15_13-45-32-32S: ['No Diagnosis Given', 'Autism Spectrum Disorder']: ['Sex_binarize']
# 2023-02-15_15-55-58-58S: ['No Diagnosis Given', 'ADHD-Inattentive Type', 'ADHD-Combined Type', 'Other Specified Attention-Deficit/Hyperactivity Disorder', 'ADHD-Hyperactive/Impulsive Type', 'Unspecified Attention-Deficit/Hyperactivity Disorder']: ['DX_01_Cat_new_binarize']
# 2023-02-15_13-56-34-34S: ['No Diagnosis Given', 'Autism Spectrum Disorder']: ['DX_01_Cat_new_binarize']
# 2023-02-15_13-51-16-16S: ['ADHD-Combined Type', 'ADHD-Inattentive Type']: ['DX_01_binarize']
# ...

# %%
from hbn.data.make_dataset import make_summary

# load model data
#MODEL_DIR = os.path.join(Defaults.MODEL_DIR, '2023-02-02_16:31:41.384700') # excluding age
MODEL_DIR = os.path.join(Defaults.MODEL_DIR, '2023-02-15_13-45-32-32S') # including age

df_classify = pd.read_csv(os.path.join(MODEL_DIR, 'classifier-all-phenotypic-models-performance.csv'))
df_classify['data'] = df_classify['data'].map({'model-data': 'null', 'model-null': 'data'})
df_feature = pd.read_csv(os.path.join(MODEL_DIR, 'classifier-feature_importance.csv'))

participant_ids = df_classify['participants'].str.split('-').iloc[0]

dx_participants = make_summary(save=False).merge(pd.DataFrame(participant_ids, columns=['Identifiers']), on='Identifiers')

target = 'Sex_binarize'

print(dx_participants['DX_01'].unique())
print(df_classify['target'].unique()[0])
# Out:
# ['No Diagnosis Given' 'Autism Spectrum Disorder']
# Sex_binarize

# %% [markdown]
# ## Models are trained to classify gender differences in participants ASD:
#
# ### Figure Description
# * Each figure describes a model (Decision Tree Classifier) trained on one measure (e.g., CELF) from a particular domain (e.g., Language Tasks)
# * Models (x axis) show ROC AUC results
#
# ### Exceptions:
# * Age and Sex are excluded from all models (except for BasicDemos model)
# * Only numeric variables are included (no categorical variables)
# * SMOTE (minor class upsampling) NOT applied to models
# * Diagnosis subtype (`DX_01`) not included as a feature in models

# %%
# set plotting style
visualize.plotting_style()

# %% [markdown]
# ## Child Measures - Language Tasks

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Child Measures') & 
                  (df_classify['domains']=='Language_Tasks')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="cb461ba1-7fd0-4610-ad51-c75a30e531db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb461ba1-7fd0-4610-ad51-c75a30e531db")) {                    Plotly.newPlot(                        "cb461ba1-7fd0-4610-ad51-c75a30e531db",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measures-CELF_Full_5to8","Child Measu
# ...

# %% [markdown]
# ## Child Measures - Cognitive Testing

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Child Measures') & 
                  (df_classify['domains']=='Cognitive_Testing')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="fcad6696-3b7c-4f78-b389-9c6086dc5dc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcad6696-3b7c-4f78-b389-9c6086dc5dc9")) {                    Plotly.newPlot(                        "fcad6696-3b7c-4f78-b389-9c6086dc5dc9",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measures-WAIS","Child Measu
# ...

# %% [markdown]
# ## Child Measures - Interview of Emotional and Psychological Function

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Child Measures') & 
                  (df_classify['domains']=='Interview_of_Emotional_and_Psychological_Function')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="4dd0713b-4cd2-409e-9e9f-64957af9de15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dd0713b-4cd2-409e-9e9f-64957af9de15")) {                    Plotly.newPlot(                        "4dd0713b-4cd2-409e-9e9f-64957af9de15",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measures-KSADS_C","Child Measure
# ...

# %% [markdown]
# ## Child Measures - Medical Status

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Child Measures') & 
                  (df_classify['domains']=='Medical_Status_Measures')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="4ce7e1d8-c561-47db-a715-90c935c32654" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ce7e1d8-c561-47db-a715-90c935c32654")) {                    Plotly.newPlot(                        "4ce7e1d8-c561-47db-a715-90c935c32654",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child Measures-PPS","Child 
# ...

# %% [markdown]
# ## Child Measures - Physical Fitness and Status

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Child Measures') & 
                  (df_classify['domains']=='Physical_Fitness_and_Status')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="b088ff46-5602-4319-b3c2-db2f91005b15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b088ff46-5602-4319-b3c2-db2f91005b15")) {                    Plotly.newPlot(                        "b088ff46-5602-4319-b3c2-db2f91005b15",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child Measures-FGA","Child 
# ...

# %% [markdown]
# ## Child Measures - Questionnaire_Measures_of_Emotional_and_Cognitive_Status

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Child Measures') & 
                  (df_classify['domains']=='Questionnaire_Measures_of_Emotional_and_Cognitive_Status')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="b8522482-50c8-4121-b3ed-5b8ba83c47fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8522482-50c8-4121-b3ed-5b8ba83c47fe")) {                    Plotly.newPlot(                        "b8522482-50c8-4121-b3ed-5b8ba83c47fe",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Child Measures-CIS_SR","Chi
# ...

# %% [markdown]
# ## Child Measures - Questionnaire_Measures_of_Family_Structure_Stress_and_Trauma

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Child Measures') & 
                  (df_classify['domains']=='Questionnaire_Measures_of_Family_Structure_Stress_and_Trauma')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="a1bc0917-8cf6-42fe-8ea7-fcc75e479672" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1bc0917-8cf6-42fe-8ea7-fcc75e479672")) {                    Plotly.newPlot(                        "a1bc0917-8cf6-42fe-8ea7-fcc75e479672",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measures-CCSC","Child Measu
# ...

# %% [markdown]
# ## Child Measures - Physiology/Motor/Neurology

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Child Measures')]

cols = ['Neurologic_Function', 'Physiologic_Function', 'Vision', 'Motor_Skills']

df1 = df1[df1['domains'].isin(cols)]

visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="e2d50304-c978-4280-98d6-d9c0edcf6748" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2d50304-c978-4280-98d6-d9c0edcf6748")) {                    Plotly.newPlot(                        "e2d50304-c978-4280-98d6-d9c0edcf6748",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measures-EEG_Track","Child Measur
# ...

# %% [markdown]
# ## Child Measures - Questionnaire_Measures_of_Substance_Use_&_Addiction

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Child Measures') & 
                  (df_classify['domains']=='Questionnaire_Measures_of_Substance_Use_&_Addiction')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="8d9867fd-fffe-4622-bb4d-89f3a0b88a20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d9867fd-fffe-4622-bb4d-89f3a0b88a20")) {                    Plotly.newPlot(                        "8d9867fd-fffe-4622-bb4d-89f3a0b88a20",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESPAD","Child Measures-ESP
# ...

# %% [markdown]
# ## Parent Measures - Demographics

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Parent Measures') & 
                  (df_classify['domains']=='Demographic_Questionnaire_Measures')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="d3748f03-7ea2-43d1-a308-d2190ea1ef68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3748f03-7ea2-43d1-a308-d2190ea1ef68")) {                    Plotly.newPlot(                        "d3748f03-7ea2-43d1-a308-d2190ea1ef68",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CB
# ...

# %% [markdown]
# ## Parent Measures - Interview of Emotional and Psychological Function

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Parent Measures') & 
                  (df_classify['domains']=='Interview_of_Emotional_and_Psychological_Function')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="cae57e7f-f1ad-43d1-bf75-79e9d184c4a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cae57e7f-f1ad-43d1-bf75-79e9d184c4a1")) {                    Plotly.newPlot(                        "cae57e7f-f1ad-43d1-bf75-79e9d184c4a1",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Parent Measures-PreInt_TxHx","Par
# ...

# %% [markdown]
# ## Parent Measures - Questionnaire_Measures_of_Family_structure_Stress_and_Trauma

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Parent Measures') & 
                  (df_classify['domains']=='Questionnaire_Measures_of_Family_structure_Stress_and_Trauma')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="46dfb22c-43c1-4144-839c-1ad20b978d93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46dfb22c-43c1-4144-839c-1ad20b978d93")) {                    Plotly.newPlot(                        "46dfb22c-43c1-4144-839c-1ad20b978d93",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Parent Measures-PCIAT","Par
# ...

# %% [markdown]
# ## Teacher - social acceptance scale and CBCL

# %%
df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['assessment']=='Teacher Measures')]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="9e943352-a038-4d69-a85e-900101efbfa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e943352-a038-4d69-a85e-900101efbfa6")) {                    Plotly.newPlot(                        "9e943352-a038-4d69-a85e-900101efbfa6",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-TRF","Teacher Measures-T
# ...

# %% [markdown]
# ## Child Behavior Checklist - Teacher and Parent

# %%
abbrevs = ['YSR', 'CBCL', 'TRF'] # 'TRF_Pre' 'CBCL_Pre'

df1 = df_classify[(df_classify['target']==target) & 
                  (df_classify['abbrevs'].isin(abbrevs))
                   ]


visualize.predictive_modeling(df=df1)
# Out:
# <div>                            <div id="6365307a-4a1f-4a3c-9ac9-e80f55b5247d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6365307a-4a1f-4a3c-9ac9-e80f55b5247d")) {                    Plotly.newPlot(                        "6365307a-4a1f-4a3c-9ac9-e80f55b5247d",                        [{"legendgroup":"data","line":{"color":"blue"},"name":"data","scalegroup":"data","side":"negative","x":["Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CBCL","Parent Measures-CB
# ...
