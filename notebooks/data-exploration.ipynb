# %%
import os
import seaborn as sns
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# %%
## get data
from hbn.models import item_analysis

df_data, df_dict, df_diagnosis = item_analysis.load_data(
                                        assessment='Parent', # Teacher, Child
                                        data_type='preprocessed'
                                        )

# merge diagnosis categorical information with data
df_data_dx = df_diagnosis[['Identifiers', 'Age', 'Sex', 'Diagnosis', 'Race', 'Ethnicity']].merge(df_data, on=['Identifiers'])
df_data_dx.columns = df_data_dx.columns.str.replace('_x', '_raw').str.replace('_y', '')
df_data_dx['Age_rounded'] = df_data_dx['Age_raw'].round()

# get ADHD
df_adhd = df_data_dx[df_data_dx['Diagnosis_raw'].str.contains('ADHD')]

# %%
p = np.percentile(a=df_adhd['Age_rounded'].tolist(), q=[15,25,35,45,55,65,75,85,95,100])

print(p)
# Out:
# [ 7.  7.  8.  9. 10. 11. 12. 13. 16. 22.]

# %%
df_adhd.groupby(['Age_rounded', 'Sex_raw']).count()['Identifiers']
# Out:
# Age_rounded  Sex_raw
# 5.0          female      13
#              male        45
# 6.0          female      45
#              male       143
# 7.0          female      63
#              male       171
# 8.0          female      76
#              male       157
# 9.0          female      63
#              male       169
# 10.0         female      62
#              male       146
# 11.0         female      46
#              male       104
# 12.0         female      36
#              male       115
# 13.0         female      25
#              male        76
# 14.0         female      20
#              male        56
# 15.0         female      15
#              male        43
# 16.0         female      12
#              male        30
# 17.0         female       8
#              male        25
# 18.0         female       5
#              male        11
# 19.0         female       1
#              male         1
# 20.0         male         4
# 21.0         female       1
# ...

# %%
246 (5,6), 234 (7), 233 (8), 232 (9), 208 (10), 150 (11), 151 (12),  177 (13,14), 159 (15-22)
