# %%
import os
import seaborn as sns
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np

from hbn.constants import Defaults
from hbn.data import data_widgets

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# interactive data widget

phenotype_widget = data_widgets.get_phenotype_inputs()
display(phenotype_widget)

participant_widget = data_widgets.get_participant_inputs()
display(participant_widget)
# Out:
# VBox(children=(Dropdown(options=('Child Measures', 'Parent Measures', 'Teacher Measures'), value='Child Measur…
# VBox(children=(Dropdown(options=('train', 'test', 'all'), value='train'), Dropdown(options=(), value=None), Se…

# %%
# get features and target
features, target = data_widgets.get_data(phenotype_widget, participant_widget, preprocess=False)

# create dataframe (merging features + target)
df = pd.concat([pd.DataFrame(target), features], axis=1)
# Out:
# reading /Users/maedbhking/Documents/healthy_brain_network/data/raw/phenotype/Parent_Measures/Interview_of_Emotional_and_Psychological_Function/Intake_Interview.csv into dataframe
# reading /Users/maedbhking/Documents/healthy_brain_network/data/raw/phenotype/Clinical_Measures/Clinical_Diagnosis_Demographics.csv into dataframe

# %%
df
# Out:
#                                                   DX_01  \
# 0                                    ADHD-Combined Type
# 1                                 ADHD-Inattentive Type
# 2                                 ADHD-Inattentive Type
# 3                                    ADHD-Combined Type
# 4                                 ADHD-Inattentive Type
# ...                                                 ...
# 1639                              ADHD-Inattentive Type
# 1640                    ADHD-Hyperactive/Impulsive Type
# 1641                              ADHD-Inattentive Type
# 1642                              ADHD-Inattentive Type
# 1643  Other Specified Attention-Deficit/Hyperactivit...
#
#      PreInt_Demos_Fam,Administration PreInt_Demos_Fam,Child_CountryOrigin  \
# 0                                All                                  USA
# 1                                All                                  USA
# 2                                All                                  USA
# 3                                All                        United States
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 1639                             All                                  USA
# 1640                             All                        United States
# 1641                             All                        United States
# 1642                             All                                  USA
# 1643                             All                        United States
#
#       PreInt_Demos_Fam,Child_Ethnicity  PreInt_Demos_Fam,Child_Race  \
# 0                                  0.0                          0.0
# 1                                  2.0                          9.0
# 2                                  0.0                          NaN
# 3                                  0.0                          0.0
# 4                                  NaN                          NaN
# ...                                ...                          ...
# 1639                               1.0                          1.0
# 1640                               0.0                          0.0
# 1641                               NaN                          0.0
# 1642                               0.0                          0.0
# 1643                               1.0                          0.0
#
#      PreInt_Demos_Fam,Child_Race_Other  PreInt_Demos_Fam,DP_Yrs  \
# 0                                  NaN                      NaN
# 1                                Mixed                      NaN
# 2                                  NaN                      NaN
# 3                                  NaN                      NaN
# 4                                  NaN                      NaN
# ...                                ...                      ...
# 1639                               NaN                      NaN
# 1640                               NaN                      NaN
# 1641                               NaN                      NaN
# 1642                               NaN                      NaN
# 1643                               NaN                      NaN
#
#      PreInt_Demos_Fam,Data_entry  PreInt_Demos_Fam,Days_Baseline  \
# 0                       Complete                            93.0
# 1                       Complete                           114.0
# 2                       Complete                           117.0
# 3                       Complete                             0.0
# 4                            NaN                             NaN
# ...                          ...                             ...
# 1639                    Complete                            56.0
# 1640                    Complete                            41.0
# 1641                    Complete                            29.0
# 1642                    Complete                            44.0
# 1643                    Complete                            29.0
#
#       PreInt_Demos_Fam,Divorced_Yrs  ... PreInt_TxHx,pmed_09_type  \
# 0                               3.0  ...                      NaN
# 1                               NaN  ...                      NaN
# 2                               NaN  ...                      NaN
# 3                               NaN  ...                      NaN
# 4                               NaN  ...                      NaN
# ...                             ...  ...                      ...
# 1639                            NaN  ...                      NaN
# 1640                            NaN  ...                      NaN
# 1641                            NaN  ...                      NaN
# 1642                            NaN  ...                      NaN
# 1643                            NaN  ...                      NaN
#
#       PreInt_TxHx,pmed_10_dose  PreInt_TxHx,pmed_10_name  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 1639                       NaN                       NaN
# 1640                       NaN                       NaN
# 1641                       NaN                       NaN
# 1642                       NaN                       NaN
# 1643                       NaN                       NaN
#
#       PreInt_TxHx,pmed_10_type PreInt_TxHx,psych_meds_cur  \
# 0                          NaN                        1.0
# 1                          NaN                        0.0
# 2                          NaN                        0.0
# 3                          NaN                        0.0
# 4                          NaN                        0.0
# ...                        ...                        ...
# 1639                       NaN                        0.0
# 1640                       NaN                        0.0
# 1641                       NaN                        0.0
# 1642                       NaN                        0.0
# 1643                       NaN                        NaN
#
#       PreInt_TxHx,psych_meds_past  PreInt_TxHx,serious_injury  \
# 0                             1.0                         1.0
# 1                             0.0                         0.0
# 2                             1.0                         0.0
# 3                             1.0                         0.0
# 4                             1.0                         0.0
# ...                           ...                         ...
# 1639                          0.0                         0.0
# 1640                          0.0                         0.0
# 1641                          0.0                         1.0
# 1642                          0.0                         0.0
# 1643                          NaN                         0.0
#
#       PreInt_TxHx,suicide  PreInt_TxHx,trauma  PreInt_TxHx,﻿EID
# 0                     0.0                 0.0               NaN
# 1                     0.0                 0.0               NaN
# 2                     0.0                 0.0               NaN
# 3                     1.0                 1.0               NaN
# 4                     0.0                 0.0               NaN
# ...                   ...                 ...               ...
# 1639                  0.0                 0.0               NaN
# 1640                  1.0                 NaN               NaN
# 1641                  0.0                 0.0               NaN
# 1642                  0.0                 0.0               NaN
# 1643                  NaN                 NaN               NaN
#
# [1644 rows x 1293 columns]

# %%
adhd = df[df["PreInt_FamHx,m_adhd"]==1].groupby('DX_01').agg({"PreInt_FamHx,m_adhd": 'count'})
total = df.groupby('DX_01').agg({"PreInt_FamHx,m_adhd": 'count'})

percent = adhd / total

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []
