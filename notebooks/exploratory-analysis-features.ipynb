# %%
import os
import seaborn as sns
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import umap

from hbn.features import build_features
from hbn.visualization import visualize as vis
from hbn.constants import Defaults

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = build_features.get_data(
                    assessment='Parent_Measures',
                    domains='Interview_of_Emotional_and_Psychological_Function',
                    measures='Intake_Interview',
                    target='DX_01_Cat_binarize',
                    min_num_participants=1000
                    )

# %%
df = pd.read_csv(os.path.join(Defaults.PHENO_DIR, 'Parent_Measures', 'Interview_of_Emotional_and_Psychological_Function', 'Intake_Interview.csv'))
