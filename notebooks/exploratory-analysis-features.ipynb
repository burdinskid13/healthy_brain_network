# %%
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import umap

from hbn.features import build_features
from hbn.visualization import visualize as vis

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# %%
df = build_features.phenotypes(
        assessment='Child Measures',
        domains='Language Tasks',
        measures=None,
        demographics=False,
        target='DX_01',
        preprocess=True
        )
# Out:
# reading /Users/maedbhking/Documents/hbn_cerebellum/data/raw/phenotype/Child_Measures/Language_Tasks/Clinical_Evaluation_of_Language_Fundamentals.csv into dataframe
# reading /Users/maedbhking/Documents/hbn_cerebellum/data/raw/phenotype/Child_Measures/Language_Tasks/Goldman-Fristoe_Test_of_Articulation_-_III.csv into dataframe
# fewer than 2000 in /Users/maedbhking/Documents/hbn_cerebellum/data/raw/phenotype/Child_Measures/Language_Tasks/Peabody_Picture_Vocabulary_Test.csv, not included as features
# reading /Users/maedbhking/Documents/hbn_cerebellum/data/raw/phenotype/Child_Measures/Language_Tasks/Test_of_Word_Reading_Efficiency_-_II.csv into dataframe
# reading /Users/maedbhking/Documents/hbn_cerebellum/data/raw/phenotype/Child_Measures/Language_Tasks/Clinical_Evaluation_of_Language_Fundamentals_-_Metalinguistics.csv into dataframe
# reading /Users/maedbhking/Documents/hbn_cerebellum/data/raw/phenotype/Child_Measures/Language_Tasks/Clinical_Evaluation_of_Language_Fundamentals__Screening_Test.csv into dataframe
# reading /Users/maedbhking/Documents/hbn_cerebellum/data/raw/phenotype/Child_Measures/Language_Tasks/Comprehensive_Test_of_Phonological_Processing_–_II.csv into dataframe
# fewer than 2000 in /Users/maedbhking/Documents/hbn_cerebellum/data/raw/phenotype/Child_Measures/Language_Tasks/Expressive_Vocabulary_Test.csv, not included as features

# %%
tmp = df.filter(like='one-hot__x0')

sns.heatmap(tmp.corr())
plt.show()
