# %%
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import umap

from hbn.features import build_features
from hbn.visualization import visualize as vis

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')
# Out:
# could not make /global/scratch/users/maedbhking/bin/pydra-ml/cache-wf/

# %%
df = build_features.get_data(
                    assessment='Parent Measures',
                    domains='Interview_of_Emotional_and_Psychological_Function',
                    measures='Intake_Interview',
                    target='DX_01_Cat_binarize',
                    min_num_participants=4000
                    )
# Out:
# reading /Users/maedbhking/Documents/healthy_brain_network/data/raw/phenotype/Parent_Measures/Interview_of_Emotional_and_Psychological_Function/Intake_Interview.csv into dataframe

# %%
df['PreInt_Demos_Fam,Child_CountryOrigin']
# Out:
# array([nan, 'United States', 'USA', 'Ecuador', 'South Korea',
#        'Congo, Democratic Republic of the (Zaire)', 'Guatemala',
#        'Nigeria', 'Puerto Rico', 'Ethiopia', 'usa', 'Japan', 'India',
#        'US', 'Sweden', 'Dominican Republic', 'Belgium', 'United Kingdom',
#        'Russia', 'France', 'Chile', 'Spain', 'Israel', 'Bulgaria',
#        'Isreal', 'Virgin Islands', 'Kenya', 'Uganda',
#        'United States (Pennsylvannia)', 'Hungary', 'Germany', 'China',
#        'Morocco', 'Norway', 'Estonia', 'America', 'Italy',
#        'Czech Republic', 'Colombia', 'Egypt', 'Australia', 'Canada',
#        'Afghanistan', 'Armenia', 'Turkey', 'Ireland', 'Yemen',
#        'Hong Kong', 'Kazakhstan', 'South Africa', 'Peru', 'New Zealand',
#        'Ukraine', 'Brazil'], dtype=object)

# %%
# Out:
# 0.0    3418
# 1.0     472
# Name: PreInt_TxHx,trauma, dtype: int64
