# %%
import os
import seaborn as sns
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np

# hbn-specific libraries - make sure you have installed (pipenv install) and activated (pipenv shell) 
# the virtual environment for this project, and make sure you have created an ipykernel for this environment (ipython kernel install --name "hbn" --user)
from hbn.constants import Defaults
from hbn.scripts import preprocess_phenotype, make_phenotype_specs
from hbn.data import make_dataset
from hbn.features.feature_selection import phenotype_features

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Child Behavior Checklist - Parent and Teacher Reports
# ### separated by preschool and school aged children
#
# ### Relevent dictionaries (in `Release9_DataDic` folder)
# * CBCL_Pre (Preschool - Parent Report)
# * CBCL (School-aged - Parent Report)
# * TRF_P (Preschool - Teacher Report)
# * TRF (School-aged - Teacher Report)

# %%
# RUN THIS CELL
# FUNCTIONS

def get_data(
    participants, 
    feature_spec, 
    cols_to_keep=['DX_01', 'DX_01_Cat', 'Age', 'Sex', 'Identifiers']
    ):
    # get data
    df = phenotype_features(
                            target_spec=None,
                            feature_spec=os.path.join(Defaults.FEATURE_DIR, feature_spec),
                            participants=participants,
                            preprocess=False,
                            drop_identifiers=False
                            )

    # get summary of clinical diagnosis + other demographics
    dx = make_dataset.make_summary(save=False)
    dx = make_dataset._add_race_ethnicity(dataframe=dx)

    # get data from intake interview and merge with clinical summary
    df = df.merge(dx[cols_to_keep], on='Identifiers')
    
    return df

def get_full_dataframe(
    spec_info,
    participants,
    cols_to_keep='Identifiers|DX_01|Age|Sex|DX_01_Cat',
    filter_scores=True,
    ):

    df_all = pd.DataFrame()
    for info in spec_info:
        # get data
        df = get_data(participants, 
                     feature_spec=info['feature_spec'],
                     cols_to_keep=list(cols_to_keep.split('|'))
                     )
        abbrev = info['code'][0]

        # load data dictionary
        dict_df = pd.read_excel(os.path.join(Defaults.PHENO_DIR, 'Release9_DataDic', abbrev.replace(',','') + '.xlsx'), header=1) 

        # remove prefix from variable values - always second column in data dic
        dict_df.rename(columns={dict_df.columns[0]: "Question", dict_df.columns[1]: "Variable"}, inplace=True)
        dict_df['Variable'] = dict_df['Variable'].str.replace(abbrev.replace(',','_'), '')

        # filter dataframe on certain columns and regex patterns
        df_filter = df.filter(regex=f'{abbrev}|{cols_to_keep}')

        # loop over diagnosis groups and melt `T_scores` column into one
        # concat each group to one dataframe
        for name, group in df_filter.groupby('DX_01'):
            group.columns = group.columns.str.replace(info['code'][1],'')
            if filter_scores:
                group = group.filter(regex=f'_T|{cols_to_keep}')
            tmp = group.melt(id_vars=list(cols_to_keep.split('|'))).rename({'variable':'T_name', 'value': 'T_scores'}, axis=1)
            tmp = tmp.merge(dict_df[['Question', 'Variable']], left_on=['T_name'], right_on=['Variable'])
            tmp['Assessment'] = info['Assessment']
            tmp['Preschool'] = info['Preschool']
            df_all = pd.concat([tmp, df_all])

    # do some clean up on existing columns
    #df_all['T_name'] = df_all['T_name'].str.rstrip('.1') # remove .1 from end of variable names
    df_all['Age_rounded'] = df_all['Age'].round()
    df_all['Question'] = df_all['Question'].str.replace("T Score", "T-Score")
    
    return df_all.reset_index(drop=True)

# %%
## RUN THIS CELL ##

# Preprocess data
#preprocess_phenotype.run()

# get specs
#make_phenotype_specs.run()


# INPUTS
participants = make_dataset.get_participants(
                            split='all', 
                            disorders=['ADHD-Combined Type', 
                                        'ADHD-Inattentive Type', 
                                        'ADHD-Hyperactive_Impulsive_Type', 
                                        'Other_Specified_Attention-Deficit_Hyperactivity_Disorder',
                                        'No_Diagnosis_Given']
                                        )



spec_info = [
    {'Assessment': 'Parent',
    'code': ['CBCL,', 'CBCL,CBCL_'],
     'Preschool': False,
     'feature_spec': 'features-Parent_Measures-Demographic_Questionnaire_Measures-Child_Behavior_Checklist-spec.json'
    }, 
    {'Assessment': 'Parent',
     'code': ['CBCL_Pre,','CBCL_Pre,CBCLPre_'],
     'Preschool': True,
     'feature_spec': 'features-Parent_Measures-Demographic_Questionnaire_Measures-Child_Behavior_Checklist-spec.json'
    },
    {'Assessment': 'Teacher',
     'code': ['TRF,','TRF,TRF_'],
     'Preschool': False,
     'feature_spec': 'features-Teacher_Measures-Child_Behavior_Checklist_–_Teacher_Report_Form-Child_Behavior_Checklist_–_Teacher_Report_Form-spec.json'
    },
    {'Assessment': 'Teacher',
    'code': ['TRF_P,', 'TRF_P,TRF_P_'],
    'Preschool': True,
    'feature_spec': 'features-Teacher_Measures-Child_Behavior_Checklist_–_Teacher_Report_Form-Child_Behavior_Checklist_–_Teacher_Report_Form-spec.json'
    }
    ]

df = get_full_dataframe(
                    spec_info=spec_info,
                    participants=participants,
                    cols_to_keep='Identifiers|DX_01|Age|Sex|DX_01_Cat',
                    filter_scores=True,
                    )

# %% [markdown]
# ## General Summary - T-Scores (Total Scores - Scaled)
# ### Presented as barplots and radar plots (note that these plots don't display error bars)
#
#
# * Teachers give lower T scores than parents, which means that parents rate their children as having more behavioral problems
# * The difference in T scores given by parent and teachers is most prominent in inattentive and combined ADHD types.
#     * These differences are similar across males and females
#     * These differences are only noticeable when children start attending school (i.e. no differences in parent/teacher reporting in preschoolers)
# * There are notable differences in T scores between children without a Diagnosis of ADHD ("No Diagnosis Given") and children with ADHD, the former have lower T scores
# * there is a slight decrease in T scores across development, but only for ADHD group

# %%
tmp = df[df['T_name']=='Total_T']

sns.barplot(data=tmp, x='DX_01', y='T_scores', hue='Assessment')
plt.xticks(rotation=45, ha='right');
plt.ylim([30,65])
plt.title('All Participants')
# Out:
# Text(0.5, 1.0, 'All Participants')

# %%
tmp = df[df['T_name']=='Total_T']

tmp = tmp.groupby(['DX_01', 'Assessment']).mean().reset_index()

fig = px.line_polar(tmp, r="T_scores", theta="DX_01", color="Assessment", line_close=True, range_r=[50,64])
fig.show()
# Out:
# <div>                            <div id="ac4f712e-a879-4606-99eb-b357845eb6f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac4f712e-a879-4606-99eb-b357845eb6f0")) {                    Plotly.newPlot(                        "ac4f712e-a879-4606-99eb-b357845eb6f0",                        [{"hovertemplate":"Assessment=Parent<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Parent","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Parent","r":[63.11436170212766,60.22641509433962,57.92878338278932,47.557993730407524,54.38834951456311,63.11436170212766],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"},{"hovertemplate":"Assessment=Teacher<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Teacher","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Teacher","r":[53.314893617021276,58.86666666666667,49.037433155080215,45.13978494623656,50.43333333333333,53.314893617021276],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555 ...

# %% [markdown]
# ## Across all ages, participants with neurodevelopmental disorders (i.e. ADHD) have higher T scores than participants without a diagnosis

# %%
tmp = df[df['T_name']=='Total_T']

sns.lineplot(data=tmp, x='Age_rounded', y='T_scores', hue='DX_01_Cat')
plt.xticks(rotation=45, ha='right');
plt.ylim([20,65])
plt.title('All Participants')
# Out:
# Text(0.5, 1.0, 'All Participants')

# %% [markdown]
# ## For female participants, teacher and parent differences are similar to group

# %%
tmp = df[(df['T_name']=='Total_T') & (df['Sex']=='female')]

sns.barplot(data=tmp, x='DX_01', y='T_scores', hue='Assessment')
plt.xticks(rotation=45, ha='right');
plt.ylim([30,70])
plt.title('Females');

# %%
tmp = df[(df['T_name']=='Total_T') & (df['Sex']=='female')]

tmp = tmp.groupby(['DX_01', 'Assessment']).mean().reset_index()

fig = px.line_polar(tmp, r="T_scores", theta="DX_01", color="Assessment", line_close=True, range_r=[50,64])
fig.show()
# Out:
# <div>                            <div id="d91950fc-3cc0-4a4e-9383-6176503a4898" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d91950fc-3cc0-4a4e-9383-6176503a4898")) {                    Plotly.newPlot(                        "d91950fc-3cc0-4a4e-9383-6176503a4898",                        [{"hovertemplate":"Assessment=Parent<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Parent","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Parent","r":[63.60818713450293,62.86206896551724,58.562790697674416,47.588235294117645,52.76923076923077,63.60818713450293],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"},{"hovertemplate":"Assessment=Teacher<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Teacher","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Teacher","r":[55.63461538461539,58.583333333333336,50.629629629629626,45.675,49.90909090909091,55.63461538461539],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"# ...

# %% [markdown]
# ## For male participants, teacher and parent differences are similar to group

# %%
tmp = df[(df['T_name']=='Total_T') & (df['Sex']=='male')]

sns.barplot(data=tmp, x='DX_01', y='T_scores', hue='Assessment')
plt.xticks(rotation=45, ha='right');
plt.ylim([30,70])
plt.title('Males');

# %%
tmp = df[(df['T_name']=='Total_T') & (df['Sex']=='male')]

tmp = tmp.groupby(['DX_01', 'Assessment']).mean().reset_index()

fig = px.line_polar(tmp, r="T_scores", theta="DX_01", color="Assessment", line_close=True, range_r=[50,64])
fig.show()
# Out:
# <div>                            <div id="be9afc5e-b414-4072-b5b2-bb66fc901996" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be9afc5e-b414-4072-b5b2-bb66fc901996")) {                    Plotly.newPlot(                        "be9afc5e-b414-4072-b5b2-bb66fc901996",                        [{"hovertemplate":"Assessment=Parent<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Parent","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Parent","r":[62.969018932874356,59.23376623376623,57.631808278867105,47.53012048192771,55.375,62.969018932874356],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"},{"hovertemplate":"Assessment=Teacher<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Teacher","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Teacher","r":[52.65573770491803,59.05555555555556,48.390977443609025,44.735849056603776,50.73684210526316,52.65573770491803],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556," ...

# %% [markdown]
# ## Only notable difference between teacher and parent reports for preschoolers is in "Other Specified/ADHD" subtype -- parents rate their children as having more behavioral problems than teachers (ADHD inattentive has too few participants to make an inference)

# %%
tmp = df[(df['T_name']=='Total_T') & (df['Preschool']==True)]

sns.barplot(data=tmp, x='DX_01', y='T_scores', hue='Assessment')
plt.xticks(rotation=45, ha='right');
plt.ylim([30,70])
plt.title('Preschoolers');

# %%
tmp = df[(df['T_name']=='Total_T') & (df['Preschool']==True)]

tmp = tmp.groupby(['DX_01', 'Assessment']).mean().reset_index()

fig = px.line_polar(tmp, r="T_scores", theta="DX_01", color="Assessment", line_close=True, range_r=[50,64])
fig.show()
# Out:
# <div>                            <div id="9eb7cb49-c40b-4910-90d6-9d4719532f8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9eb7cb49-c40b-4910-90d6-9d4719532f8d")) {                    Plotly.newPlot(                        "9eb7cb49-c40b-4910-90d6-9d4719532f8d",                        [{"hovertemplate":"Assessment=Parent<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Parent","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Parent","r":[60.725,62.05882352941177,50.0,47.26086956521739,40.0,60.725],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"},{"hovertemplate":"Assessment=Teacher<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Teacher","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Teacher","r":[59.148148148148145,62.5,60.5,50.166666666666664,59.5,59.148148148148145],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888 ...

# %% [markdown]
# ## Preschoolers with hyperactive/impulsive subtype are rated as having more behavioral problems than their older counterparts

# %%
tmp = df[(df['T_name']=='Total_T')]
tmp['Preschool_cat'] = tmp['Preschool'].map({True: 'Preschool', False: 'Elementary/Middle School'})

tmp = tmp.groupby(['DX_01', 'Preschool_cat']).mean().reset_index()

fig = px.line_polar(tmp, r="T_scores", theta="DX_01", color="Preschool_cat", line_close=True, range_r=[50,64])
fig.show()
# Out:
# <div>                            <div id="0ec6dd9d-36c2-4a7a-b2c9-7a53aff95d6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ec6dd9d-36c2-4a7a-b2c9-7a53aff95d6f")) {                    Plotly.newPlot(                        "0ec6dd9d-36c2-4a7a-b2c9-7a53aff95d6f",                        [{"hovertemplate":"Preschool_cat=Elementary/Middle School<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Elementary/Middle School","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Elementary/Middle School","r":[60.83152173913044,59.357798165137616,56.01533018867924,46.89655172413793,53.826771653543304,60.83152173913044],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"},{"hovertemplate":"Preschool_cat=Preschool<br>T_scores=%{r}<br>DX_01=%{theta}<extra></extra>","legendgroup":"Preschool","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Preschool","r":[60.08955223880597,62.22222222222222,54.84615384615385,48.25714285714286,46.5,60.08955223880597],"showlegend":true,"subplot":"polar","theta":["ADHD-Combined Type","ADHD-Hyperactive/Impulsive Type","ADHD-Inattentive Type","No Diagnosis Given","Other Specified Attention-Deficit/Hyperactivity Disorder","ADHD-Combined Type"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"# ...

# %% [markdown]
# ## T scores across all participants

# %%
tmp = df[(df['T_name']=='Total_T')]

fig = px.scatter(tmp, x="Identifiers", y="T_scores", color="DX_01",
                hover_name="DX_01", log_x=False, size_max=60) # size="Age"
fig.update_layout(showlegend=False)
fig.update_xaxes(showticklabels=False, title='Participants')
fig.show()
# Out:
# <div>                            <div id="cfc1f297-2ca1-4d0b-8b48-3041dbf87ef1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfc1f297-2ca1-4d0b-8b48-3041dbf87ef1")) {                    Plotly.newPlot(                        "cfc1f297-2ca1-4d0b-8b48-3041dbf87ef1",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>DX_01=Other Specified Attention-Deficit/Hyperactivity Disorder<br>Identifiers=%{x}<br>T_scores=%{y}<extra></extra>","hovertext":["Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity Disorder","Other Specified Attention-Deficit/Hyperactivity D ...

# %% [markdown]
# ## T scores for male and female participants with ADHD

# %%
tmp = df[(df['T_name']=='Total_T') & (df['DX_01_Cat']=='Neurodevelopmental Disorders')]

fig = px.scatter(tmp, x="Identifiers", y="T_scores", color="Sex",
                hover_name="Sex", log_x=False, size_max=60) # size="Age"
fig.update_layout(showlegend=False)
fig.update_xaxes(showticklabels=False, title='Participants')
fig.show()
# Out:
# <div>                            <div id="9174de71-1ace-4199-9a13-27a33a474995" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9174de71-1ace-4199-9a13-27a33a474995")) {                    Plotly.newPlot(                        "9174de71-1ace-4199-9a13-27a33a474995",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Sex=female<br>Identifiers=%{x}<br>T_scores=%{y}<extra></extra>","hovertext":["female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female" ...

# %% [markdown]
# ## General Summary - DSM Scores
# ### Children with neurodevelopmental disorders (i.e. ADHD diagnoses) have on average higher T scores on all DSM categories

# %%
tmp = df[df['T_name'].str.find('DSM')==0]


sns.barplot(data=tmp, x='Question', y='T_scores', hue='DX_01_Cat')
plt.xticks(rotation=45, ha='right');
plt.ylim([30,75])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('');

# %% [markdown]
# ## General Sumary - Syndrome Scale Scores
# ### Children with neurodevelopmental disorders (i.e. ADHD diagnoses) have on average higher T scores on all Syndrome Scales

# %%
tmp = df[df['T_name'].str.find('DSM')==-1]

sns.barplot(data=tmp, x='Question', y='T_scores', hue='DX_01_Cat')
plt.xticks(rotation=45, ha='right');
plt.ylim([30,75])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('');

# %% [markdown]
# ## Radar Plots - another way of visualizing the barplots
# ### error bars aren't represented here - these are average scores

# %%
tmp = df[df['T_name'].str.find('DSM')==-1]

tmp = tmp.groupby(['DX_01_Cat', 'Question']).mean().reset_index()

fig = px.line_polar(tmp, r="T_scores", theta="Question", color="DX_01_Cat", line_close=True, range_r=[50,68])
fig.show()
# Out:
# <div>                            <div id="4b6ca57c-e152-4976-8fad-b2850a2a986a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b6ca57c-e152-4976-8fad-b2850a2a986a")) {                    Plotly.newPlot(                        "4b6ca57c-e152-4976-8fad-b2850a2a986a",                        [{"hovertemplate":"DX_01_Cat=Neurodevelopmental Disorders<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"Neurodevelopmental Disorders","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Neurodevelopmental Disorders","r":[60.467170524326875,57.6551724137931,65.47756258856873,61.266666666666666,65.17777777777778,57.648648648648646,60.06666666666667,56.45801158301158,57.43413173652694,58.6764705882353,59.56437125748503,56.81199811053377,59.996007984031934,58.3230987246103,60.23893805309734,57.98802395209581,60.467170524326875],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"},{"hovertemplate":"DX_01_Cat=No Diagnosis Given<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"No Diagnosis Given","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"No Diagnosis Given","r":[53.800970873786405,53.28155339805825,55.35679611650485,55.166666666666664,54.333333333333336,48.3475,50.083333333333336,48.46,53.249336870026525,54.391304347826086,53.785145888594165,53.96116504854369,53.69230769230769,47.012135922330096,53.4,53.84084880636605,53.800970873786405],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl ...

# %%
tmp = df[df['T_name'].str.find('DSM')==0]

tmp = tmp.groupby(['DX_01_Cat', 'Question']).mean().reset_index()

fig = px.line_polar(tmp, r="T_scores", theta="Question", color="DX_01_Cat", line_close=True, range_r=[50,65])
fig.show()
# Out:
# <div>                            <div id="71264a6a-c6d3-4143-9b76-868e9e99c69b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71264a6a-c6d3-4143-9b76-868e9e99c69b")) {                    Plotly.newPlot(                        "71264a6a-c6d3-4143-9b76-868e9e99c69b",                        [{"hovertemplate":"DX_01_Cat=Neurodevelopmental Disorders<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"Neurodevelopmental Disorders","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Neurodevelopmental Disorders","r":[59.0,56.99454545454545,63.77090909090909,60.93333333333333,58.46681922196797,59.70331950207469,59.7,59.86764705882353,53.04118993135011,59.0],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"DX_01_Cat=No Diagnosis Given<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"No Diagnosis Given","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"No Diagnosis Given","r":[53.34782608695652,53.206896551724135,55.758620689655174,54.916666666666664,53.839506172839506,54.25806451612903,55.060344827586206,51.56521739130435,51.074074074074076,53.34782608695652],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale" ...

# %% [markdown]
# ## Children with Hyperactive/Impulsive subtype have highest scores on 5 DSM measures:  oppositional defiant problems, conduct problems, developmental problems, depressive problems, and anxiety)
#
# Multivariate information for ADHD subtypes and T Scores is plotted here using radar plots -- too much information to plot on a barplot

# %%
tmp = df[(df['T_name'].str.find('DSM')==0)]

tmp = tmp.groupby(['DX_01', 'Question']).mean().reset_index()

fig = px.line_polar(tmp, r="T_scores", theta="Question", color="DX_01", line_close=True, range_r=[50,70])
fig.show()
# Out:
# <div>                            <div id="e490cc27-6b3a-44c6-906d-7291d70e072d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e490cc27-6b3a-44c6-906d-7291d70e072d")) {                    Plotly.newPlot(                        "e490cc27-6b3a-44c6-906d-7291d70e072d",                        [{"hovertemplate":"DX_01=ADHD-Combined Type<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"ADHD-Combined Type","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ADHD-Combined Type","r":[60.3,57.75636363636364,66.06545454545454,59.629629629629626,60.44711538461539,59.97446808510638,61.66909090909091,59.75,53.28365384615385,60.3],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"DX_01=ADHD-Hyperactive/Impulsive Type<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"ADHD-Hyperactive/Impulsive Type","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ADHD-Hyperactive/Impulsive Type","r":[59.94117647058823,58.59574468085106,65.80851063829788,62.3,67.05,60.96666666666667,65.0,63.1764705882353,51.0,59.94117647058823],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"DX_01=ADHD-Inattentive Type<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"ADHD-Inattentive Type","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ADHD-Inattentive Type","r":[54.42857142857143,56.04123711340206,60.49484536082474,63.5,55.30939226519337,59.224598930481285,55.902061855670105,56.857142857142854,53.06077348066298,54.42857142857143],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"DX_01=No Diagnosis Given<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"No Diagnosis Given","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"No Diagnosis Given","r":[53.34782608695652,53.206896551724135,55.758620689655174,54.916666666666664,53.839506172839506,54.25806451612903,55.060344827586206,51.56521739130435,51.074074074074076,53.34782608695652],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"DX_01=Other Specified Attention-Deficit/Hyperactivity Disorder<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"Other Specified Atte ...

# %% [markdown]
# ## Syndrome Scale scores across ADHD subtypes
# * Children with inattentive type have highest scores on the following measures: withdrawn, emotional reaction, internalizing problems
# * Children with Combined type have highest scores on the following measures (followed closely by hyperactive/impulsive type): rule breaking, sleep problems, social problems, somatic complaints, thought problems, attention problems

# %%
tmp = df[(df['T_name'].str.find('DSM')==-1)]

tmp = tmp.groupby(['DX_01', 'Question']).mean().reset_index()

fig = px.line_polar(tmp, r="T_scores", theta="Question", color="DX_01", line_close=True, range_r=[50,70])
fig.show()
# Out:
# <div>                            <div id="163a1d86-efce-4d47-b585-5421e981df9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("163a1d86-efce-4d47-b585-5421e981df9b")) {                    Plotly.newPlot(                        "163a1d86-efce-4d47-b585-5421e981df9b",                        [{"hovertemplate":"DX_01=ADHD-Combined Type<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"ADHD-Combined Type","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ADHD-Combined Type","r":[63.40932117527862,58.737588652482266,67.56636271529888,60.370370370370374,64.25925925925925,61.31979166666667,58.81481481481482,57.64270833333333,59.483695652173914,61.025,61.25,57.243161094224924,62.05543478260869,60.78115501519757,59.83582089552239,57.870652173913044,63.40932117527862],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"},{"hovertemplate":"DX_01=ADHD-Hyperactive/Impulsive Type<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"ADHD-Hyperactive/Impulsive Type","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ADHD-Hyperactive/Impulsive Type","r":[64.30882352941177,57.19117647058823,63.705882352941174,61.5,70.0,61.34126984126984,59.9,56.0,59.091743119266056,57.705882352941174,59.944954128440365,56.330882352941174,60.20183486238532,59.9264705882353,60.851851851851855,57.56880733944954,64.30882352941177],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"},{"hovertemplate":"DX_01=ADHD-Inattentive Type<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"ADHD-Inattentive Type","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ADHD-Inattentive Type","r":[56.91869918699187,56.86062717770035,64.08246225319397,68.33333333333333,61.666666666666664,53.62105263157895,66.66666666666667,55.85730994152047,55.28891509433962,52.42857142857143,57.9186320754717,56.628339140534266,58.238207547169814,55.99767711962834,62.69230769230769,58.50235849056604,56.91869918699187],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"},{"hovertemplate":"DX_01=No Diagnosis Given<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"No Diagnosis Given","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circl ...

# %% [markdown]
# ## DSM scores across M/F for each ADHD subtype
# * Girls with adhd combined type have higher scores on 7/9 measures, particularly on affective and ADHD scores
# * Boys with hyperactive/impulsive adhd have higher scores than girls on almost all measures
# * Boys with inattentive adhd have higher ASD scores, and other scores are roughly similar across M and F
# * Children with no diagnoses have roughly similar scores on all measures, except that girls have higher scores on affective problems
# * Girls with other specified attention-deficit/ADHD subtype have sig. higher ASD problems score

# %%
tmp = df[(df['T_name'].str.find('DSM')==0)]

for name, group in tmp.groupby('DX_01'):
    group = group.groupby(['Question', 'Sex']).mean().reset_index()
    fig = px.line_polar(group, r="T_scores", theta="Question", color="Sex", line_close=True, range_r=[50,75], title=name)
    fig.show()
# Out:
# <div>                            <div id="8c9c859b-95e7-403a-938a-a8b74e80d5db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c9c859b-95e7-403a-938a-a8b74e80d5db")) {                    Plotly.newPlot(                        "8c9c859b-95e7-403a-938a-a8b74e80d5db",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[64.0,58.296875,70.96875,58.333333333333336,62.04347826086956,60.32692307692308,63.75,60.666666666666664,52.630434782608695,64.0],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[58.714285714285715,57.59241706161137,64.5781990521327,60.0,59.99382716049383,59.87431693989071,61.03791469194313,59.357142857142854,53.46913580246913,58.714285714285715],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...
# <div>                            <div id="e2a9f470-e516-4cfc-a9bb-6a6dda2e0734" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2a9f470-e516-4cfc-a9bb-6a6dda2e0734")) {                    Plotly.newPlot(                        "e2a9f470-e516-4cfc-a9bb-6a6dda2e0734",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[55.0,55.94117647058823,65.17647058823529,56.25,67.25,60.666666666666664,63.588235294117645,62.0,52.5,55.0],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[62.0,60.1,66.16666666666667,66.33333333333333,66.91666666666667,61.166666666666664,65.8,63.666666666666664,50.0,62.0],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...
# <div>                            <div id="cbf33fe4-db8e-4f12-a529-b5cd07061060" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbf33fe4-db8e-4f12-a529-b5cd07061060")) {                    Plotly.newPlot(                        "cbf33fe4-db8e-4f12-a529-b5cd07061060",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[53.5,55.12068965517241,61.172413793103445,58.5,55.59615384615385,59.75925925925926,54.98275862068966,56.5,53.82692307692308,53.5],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[55.666666666666664,56.43382352941177,60.205882352941174,66.0,55.1937984496124,59.00751879699248,56.294117647058826,57.333333333333336,52.751937984496124,55.666666666666664],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5 ...
# <div>                            <div id="2b0b9396-3784-4694-a8f0-5d7935123d70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b0b9396-3784-4694-a8f0-5d7935123d70")) {                    Plotly.newPlot(                        "2b0b9396-3784-4694-a8f0-5d7935123d70",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[51.7,54.34,56.16,54.6,53.02857142857143,53.925,54.88,51.4,50.857142857142854,51.7],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[54.61538461538461,52.34848484848485,55.45454545454545,55.142857142857146,54.45652173913044,54.509433962264154,55.196969696969695,51.69230769230769,51.23913043478261,54.61538461538461],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666 ...
# <div>                            <div id="e2269e77-d8c2-4d13-8088-3c77d4af28db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2269e77-d8c2-4d13-8088-3c77d4af28db")) {                    Plotly.newPlot(                        "e2269e77-d8c2-4d13-8088-3c77d4af28db",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[50.0,52.30769230769231,61.61538461538461,74.0,58.5,56.36363636363637,58.15384615384615,50.5,51.4,50.0],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[50.0,55.142857142857146,60.76190476190476,54.0,57.77777777777778,61.0,58.095238095238095,54.0,53.22222222222222,50.0],"showlegend":true,"subplot":"polar","theta":["Affective Problems T-Score","Anxiety Problems T-Score","Attention Deficit/Hyperactivity Problems T-Score","Autism Spectrum Problems T-Score","Conduct Problems T-Score","Depressive Problems T-Score","Oppositional Defiant Problems T-Score","Pervasive Development Problems T-Scre","Somatic Problems T-Score","Affective Problems T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...

# %% [markdown]
# ## Syndrome Scale Scores across M/F for each ADHD subtype
# * girls with adhd combined type have hgiher scores on attention problems and sleep problems
# * boys with hyperactive type have higher scores on externalizing and internalizing problems
# * boys with inattentive type have higher scores on emotional reaction and internalizing problems
# * girls with other specified/hyperactive type have higher scores on externalizing and internalizing problems

# %%
tmp = df[(df['T_name'].str.find('DSM')==-1)]

for name, group in tmp.groupby('DX_01'):
    group = group.groupby(['Question', 'Sex']).mean().reset_index()
    fig = px.line_polar(group, r="T_scores", theta="Question", color="Sex", line_close=True, range_r=[50,75], title=name)
    fig.show()
# Out:
# <div>                            <div id="cc0f7e7e-fe7c-4fb3-a085-787296e19f39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc0f7e7e-fe7c-4fb3-a085-787296e19f39")) {                    Plotly.newPlot(                        "cc0f7e7e-fe7c-4fb3-a085-787296e19f39",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[63.82511210762332,58.511210762331835,70.57399103139014,61.333333333333336,66.66666666666667,62.06912442396313,59.333333333333336,57.1705069124424,60.41951219512195,68.16666666666667,61.829268292682926,57.53363228699551,62.453658536585365,61.74887892376682,60.0,56.234146341463415,63.82511210762332],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[63.287958115183244,58.803664921465966,66.68848167539267,60.095238095238095,63.57142857142857,61.100942126514134,58.666666666666664,57.780619111709285,59.215384615384615,57.964285714285715,61.08391608391609,57.15837696335078,61.94125874125874,60.49869109947644,59.775510204081634,58.33986013986014,63.287958115183244],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"], ...
# <div>                            <div id="ad49bacf-045e-431f-856a-a7807e691cdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad49bacf-045e-431f-856a-a7807e691cdd")) {                    Plotly.newPlot(                        "ad49bacf-045e-431f-856a-a7807e691cdd",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[65.92682926829268,57.68292682926829,66.46341463414635,52.0,66.5,64.05405405405405,53.25,58.24324324324324,61.625,53.2,62.71875,57.90243902439025,61.8125,61.609756097560975,58.888888888888886,59.125,65.92682926829268],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[63.61052631578947,56.97894736842105,62.51578947368421,67.83333333333333,72.33333333333333,60.21348314606742,64.33333333333333,55.06741573033708,58.03896103896104,59.583333333333336,58.79220779220779,55.65263157894737,59.532467532467535,59.2,61.833333333333336,56.922077922077925,63.61052631578947],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444 ...
# <div>                            <div id="9f218c3e-2ab0-4e7f-a2f3-d4ca23dd2e98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f218c3e-2ab0-4e7f-a2f3-d4ca23dd2e98")) {                    Plotly.newPlot(                        "9f218c3e-2ab0-4e7f-a2f3-d4ca23dd2e98",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[56.973977695167285,57.03345724907063,65.92565055762081,63.0,60.5,54.09737827715356,58.0,56.176029962546814,55.79847908745247,52.0,58.00760456273764,56.985130111524164,58.041825095057035,56.97026022304833,62.333333333333336,58.19391634980989,56.973977695167285],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[56.89358108108108,56.7820945945946,63.244932432432435,71.0,62.25,53.404761904761905,71.0,55.71258503401361,55.05982905982906,53.0,57.878632478632476,56.46621621621622,58.32649572649573,55.55574324324324,63.0,58.64102564102564,56.89358108108108],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444444 ...
# <div>                            <div id="37aa6d50-c5b5-46d9-b37c-1ce57c017681" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37aa6d50-c5b5-46d9-b37c-1ce57c017681")) {                    Plotly.newPlot(                        "37aa6d50-c5b5-46d9-b37c-1ce57c017681",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[53.64766839378238,53.33678756476684,56.020725388601036,57.0,53.0,48.452127659574465,47.4,48.5531914893617,53.247191011235955,54.5,53.91011235955056,54.35233160621762,53.12359550561798,47.19170984455958,51.86666666666667,53.57865168539326,53.64766839378238],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[53.93607305936073,53.23287671232877,54.77168949771689,53.857142857142854,55.285714285714285,48.25471698113208,52.0,48.37735849056604,53.25125628140704,54.30769230769231,53.67336683417086,53.61643835616438,54.20100502512563,46.853881278538815,54.55,54.07537688442211,53.93607305936073],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333 ...
# <div>                            <div id="79e6eb7d-c8da-4c19-8089-005fa496dc88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79e6eb7d-c8da-4c19-8089-005fa496dc88")) {                    Plotly.newPlot(                        "79e6eb7d-c8da-4c19-8089-005fa496dc88",                        [{"hovertemplate":"Sex=female<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"female","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"female","r":[57.4,53.48,60.38,52.0,70.0,53.10204081632653,62.0,48.61224489795919,55.808510638297875,50.0,56.212765957446805,53.44,53.93617021276596,52.14,56.666666666666664,54.59574468085106,57.4],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"},{"hovertemplate":"Sex=male<br>T_scores=%{r}<br>Question=%{theta}<extra></extra>","legendgroup":"male","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","r":[57.8433734939759,56.30120481927711,61.08433734939759,50.0,58.0,53.707317073170735,54.0,54.24390243902439,55.3,50.5,59.075,56.40963855421687,58.225,54.31325301204819,56.666666666666664,56.45,57.8433734939759],"showlegend":true,"subplot":"polar","theta":["Aggressive Behavior T-Score","Anxious/Depressed T-Score","Attention Problems T-Score","Emotionally Reaction T-Score","Externalizing Problems T-Score","Externalizing T-Score","Internalizing Problems T-Score","Internalizing T-Score","Rule Breaking Behavior T-Score","Sleep Problems T-Score","Social Problems T-Score","Somatic Complaints T-Score","Thought Problems T-Score","Total T-Score","Withdrawn T-Score","Withdrawn/Depressed T-Score","Aggressive Behavior T-Score"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888 ...

# %% [markdown]
# ## Specific Questions of Interest from Child Behavior Checklist
# ### Are there specific items from the CBCL (Preschool or Older; Teacher or Parent) that we want to investigate?
